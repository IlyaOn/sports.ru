# %%
import pandas as pd

# %%
df = pd.read_csv('./dataset_Facebook.csv', sep=';')
# Проверим, что таблица считалась корректно
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # выведем информацию о типах

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
# Page total likes                                                       500 non-null int64
# Type                                                                   500 non-null object
# Category                                                               500 non-null int64
# Post Month                                                             500 non-null int64
# Post Weekday                                                           500 non-null int64
# Post Hour                                                              500 non-null int64
# Paid                                                                   499 non-null float64
# Lifetime Post Total Reach                                              500 non-null int64
# Lifetime Post Total Impressions                                        500 non-null int64
# ...

# %% [markdown]
# * Видим, что только один столбец содержит не числовые поля, выделем их в отдельный фрейм и посчитаем статистики

# %% [markdown]
# # Числовые признаки

# %%
df_num = df.drop(columns=['Type'])
df_num_stat = df_num.describe()

df_num_stat
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
# Выведем отдельно значение арифм. средне, min, max и медианы (50% квантиль)
df_statistic.loc[['mean', 'max', 'min', '50%']]
# Out:
#       Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# mean        123194.176      1.88       7.038          4.15       7.84
# max         139441.000      3.00      12.000          7.00      23.00
# min          81370.000      1.00       1.000          1.00       1.00
# 50%         129600.000      2.00       7.000          4.00       9.00
#
#           Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# mean  0.278557                   13903.36                        29585.948
# max   1.000000                  180480.00                      1110282.000
# min   0.000000                     238.00                          570.000
# 50%   0.000000                    5281.00                         9051.000
#
#       Lifetime Engaged Users  Lifetime Post Consumers  \
# mean                 920.344                  798.772
# max                11452.000                11328.000
# min                    9.000                    9.000
# ...

# %%
# посчитаем моду
df_num.mode()
# Out:
#     Page total likes  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 0           136393.0       1.0        10.0           7.0        3.0   0.0
# 1                NaN       NaN         NaN           NaN        NaN   NaN
# 2                NaN       NaN         NaN           NaN        NaN   NaN
# 3                NaN       NaN         NaN           NaN        NaN   NaN
# 4                NaN       NaN         NaN           NaN        NaN   NaN
# 5                NaN       NaN         NaN           NaN        NaN   NaN
# 6                NaN       NaN         NaN           NaN        NaN   NaN
# 7                NaN       NaN         NaN           NaN        NaN   NaN
# 8                NaN       NaN         NaN           NaN        NaN   NaN
# 9                NaN       NaN         NaN           NaN        NaN   NaN
# 10               NaN       NaN         NaN           NaN        NaN   NaN
# 11               NaN       NaN         NaN           NaN        NaN   NaN
# ...

# %% [markdown]
# * Видим, что в некоторых столбцах несколько мод, причем в столбце _Lifetime Post reach by people who like your Page_ их аж 30
# * Чтобы унифицировать значения моды, мы возьмем только первое значение

# %%
df_num.mode().iloc[[0]]
# Out:
#    Page total likes  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 0          136393.0       1.0        10.0           7.0        3.0   0.0
#
#    Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                      677.0                           4372.0
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                   537.0                    182.0
#
#    Lifetime Post Consumptions  \
# 0                       431.0
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                             1210.0
#
#    Lifetime Post reach by people who like your Page  \
# 0                                               690
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                              403.0
#
#    comment  like  share  Total Interactions
# 0      0.0  98.0   13.0                 0.0

# %% [markdown]
# # Строковы признаки (Type)

# %%
df_type = df[['Type']]

# %%
# Посчитыаем кол-во каждого значения в массиве
df.groupby('Type').size()
# Out:
# Type
# Link       22
# Photo     426
# Status     45
# Video       7
# dtype: int64

# %% [markdown]
# * Отсюда видно, что мода = 'Photo'

# %% [markdown]
# # Самый популярный объект в выборке

# %%
# Размер выборки без дубликатов
df.drop_duplicates().shape
# Out:
# (500, 19)

# %%
# размер выборки с возможным дубликатами
df.shape
# Out:
# (500, 19)

# %% [markdown]
# * Видим, что высе объекты в выборке уникальны, и "самого популярного" среди них нет
